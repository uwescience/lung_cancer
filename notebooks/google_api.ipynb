# %% [markdown]
# # GOOGLE API

# %%
from google import genai
import os

# %%
# Set up the key
with open("/Users/jlheller/google_api_key_paid.txt", "r") as f:
    gemini_api_key = f.read()
os.environ["GEMINI_API_KEY"] = gemini_api_key

# %%
# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI learns patterns from data to make predictions or decisions.

# %%
client = genai.Client()
chat = client.chats.create(model="gemini-2.5-flash")

response = chat.send_message("I have 2 dogs in my house.")
print(response.text)

if True:
    # reset context
    # To reset, just create a new chat
    chat = client.chats.create(model="gemini-2.0-flash")  # Fresh session

response = chat.send_message("How many paws are in my house?")
print(response.text)

for message in chat.get_history():
    print(f'role - {message.role}',end=": ")
    print(message.parts[0].text)
# Out:
# Oh, how wonderful! Dogs bring so much joy and companionship to a home.
#
# Do you want to tell me a bit about them? What are their names or breeds?
# To figure out how many paws are in your house, I need some information! Tell me:
#
# *   **Do you have any pets?** If so, what kind and how many of each? (e.g., 2 dogs, 1 cat, 0 hamsters)
# *   **Are there any other animals in your house?** (e.g., visiting pets, stuffed animals that look like they have paws, etc.)
# *   **Are there any humans in your house?** (while humans have feet, some people might playfully refer to them as paws!)
#
# Once I have this information, I can calculate the number of paws.
#
# role - user: How many paws are in my house?
# role - model: To figure out how many paws are in your house, I need some information! Tell me:
#
# *   **Do you have any pets?** If so, what kind and how many of each? (e.g., 2 dogs, 1 cat, 0 hamsters)
# *   **Are there any other animals in your house?** (e.g., visiting pets, stuffed animals that look like they have paws, etc.)
# *   **Are there any humans in your house?** (while humans have feet, some people might playfully refer to them as paws!)
#
# Once I have this information, I can calculate the number of paws.

# %%
type(chat)
# Out:
# google.genai.chats.Chat
